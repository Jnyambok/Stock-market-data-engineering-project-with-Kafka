# %%
# !pip install kafka-python
# !pip install s3fs
# Out:
# Requirement already satisfied: kafka-python in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Collecting s3fs
#   Downloading s3fs-2024.12.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting aiobotocore<3.0.0,>=2.5.4 (from s3fs)
#   Downloading aiobotocore-2.18.0-py3-none-any.whl.metadata (23 kB)
# Collecting fsspec==2024.12.0.* (from s3fs)
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from s3fs) (3.11.11)
# Collecting aioitertools<1.0.0,>=0.5.1 (from aiobotocore<3.0.0,>=2.5.4->s3fs)
#   Downloading aioitertools-0.12.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting botocore<1.36.2,>=1.36.0 (from aiobotocore<3.0.0,>=2.5.4->s3fs)
#   Downloading botocore-1.36.1-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.11/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (2.8.2)
# Collecting jmespath<2.0.0,>=0.7.1 (from aiobotocore<3.0.0,>=2.5.4->s3fs)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in /usr/local/lib/python3.11/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (6.1.0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.11/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (2.3.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /usr/local/lib/python3.11/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (1.17.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.5.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.18.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0.0,>=2.1->aiobotocore<3.0.0,>=2.5.4->s3fs) (1.17.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.11/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (3.10)
# Downloading s3fs-2024.12.0-py3-none-any.whl (30 kB)
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 10.4 MB/s eta 0:00:00
# Downloading aiobotocore-2.18.0-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.6/77.6 kB 7.2 MB/s eta 0:00:00
# Downloading aioitertools-0.12.0-py3-none-any.whl (24 kB)
# Downloading botocore-1.36.1-py3-none-any.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 60.9 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Installing collected packages: jmespath, fsspec, aioitertools, botocore, aiobotocore, s3fs
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.12.0 which is incompatible.
# Successfully installed aiobotocore-2.18.0 aioitertools-0.12.0 botocore-1.36.1 fsspec-2024.12.0 jmespath-1.0.1 s3fs-2024.12.0

# %%
import pandas as pd
from kafka import KafkaConsumer, KafkaProducer
from time import sleep
from json import dumps,loads
import json

# %%
consumer = KafkaConsumer('demo_testing2',
                         bootstrap_servers=['16.171.32.64:9092'],
                         value_deserializer=lambda x: loads(x.decode('utf-8')))
# Out:
# WARNING:kafka.coordinator.consumer:group_id is None: disabling auto-commit.

# %%
#for c in consumer:
    #print(c.value)
# Out:
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat poll expired, leaving group
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat failed for group consumer-group-a because it is rebalancing
# WARNING:kafka.coordinator:Heartbeat poll expired, leaving group
# {'Index': '399001.SZ', 'Date': '2004-03-31', 'Open': 4018.830078, 'High': 4061.669922, 'Low': 4008.0, 'Close': 4060.139893, 'Adj Close': 4060.094482, 'Volume': 22400.0, 'CloseUSD': 649.62238288}
# {'Index': 'N225', 'Date': '1966-12-21', 'Open': 1404.300049, 'High': 1404.300049, 'Low': 1404.300049, 'Close': 1404.300049, 'Adj Close': 1404.300049, 'Volume': 0.0, 'CloseUSD': 14.04300049}
# {'Index': 'NYA', 'Date': '1979-04-27', 'Open': 606.929993, 'High': 606.929993, 'Low': 606.929993, 'Close': 606.929993, 'Adj Close': 606.929993, 'Volume': 0.0, 'CloseUSD': 606.929993}
# {'Index': '000001.SS', 'Date': '2014-11-18', 'Open': 2474.181885, 'High': 2477.052002, 'Low': 2449.812988, 'Close': 2457.529053, 'Adj Close': 2457.529053, 'Volume': 201100.0, 'CloseUSD': 393.20464848000006}
# {'Index': 'NYA', 'Date': '2013-07-15', 'Open': 9506.459961, 'High': 9531.660156, 'Low': 9496.919922, 'Close': 9520.950195, 'Adj Close': 9520.950195, 'Volume': 2623200000.0, 'CloseUSD': 9520.950195}
# {'Index': 'GDAXI', 'Date': '1989-09-08', 'Open': 1654.469971, 'High': 1654.469971, 'Low': 1654.469971, 'Close': 1654.469971, 'Adj Close': 1654.469971, 'Volume': 0.0, 'CloseUSD': 2018.45336462}
# {'Index': 'N100', 'Date': '2002-02-12', 'Open': 765.090027, 'High': 768.340027, 'Low': 755.570007, 'Close': 758.570007, 'Adj Close': 758.570007, 'Volume': 0.0, 'CloseUSD': 925.45540854}
# {'Index': 'GSPTSE', 'Date': '2017-10-27', 'Open': 15902.90039, 'High': 15963.59961, 'Low': 15872.90039, 'Close': 15953.5, 'Adj Close': 15953.5, 'Volume': 20959390000.0, 'CloseUSD': 13241.405}
# {'Index': 'GDAXI', 'Date': '1998-07-24', 'Open': 5990.47998, 'High': 6062.029785, 'Low': 5952.819824, 'Close': 6040.580078, 'Adj Close': 6040.580078, 'Volume': 0.0, 'CloseUSD': 7369.507695159999}
# {'Index': 'SSMI', 'Date': '2017-03-28', 'Open': 8610.19043, 'High': 8629.240234, 'Low': 8568.179688, 'Close': 8597.019531, 'Adj Close': 8597.019531, 'Volume': 51996900.0, 'CloseUSD': 9542.691679410002}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-d718415e1172> in <cell line: 0>()
# ----> 1 for c in consumer:
#       2     print(c.value)
#
# /usr/local/lib/python3.11/dist-packages/kafka/consumer/group.py in __next__(self)
#    1191             return self.next_v1()
#    1192         else:
# -> 1193             return self.next_v2()
#    1194
#    1195     def next_v2(self):
#
# /usr/local/lib/python3.11/dist-packages/kafka/consumer/group.py in next_v2(self)
#    1199                 self._iterator = self._message_generator_v2()
#    1200             try:
# -> 1201                 return next(self._iterator)
#    1202             except StopIteration:
#    1203                 self._iterator = None
#
# /usr/local/lib/python3.11/dist-packages/kafka/consumer/group.py in _message_generator_v2(self)
#    1114     def _message_generator_v2(self):
#    1115         timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116         record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117         for tp, records in six.iteritems(record_map):
#    1118             # Generators are stateful, and it is possible that the tp / records
#
# /usr/local/lib/python3.11/dist-packages/kafka/consumer/group.py in poll(self, timeout_ms, max_records, update_offsets)
#     653         remaining = timeout_ms
#     654         while True:
# --> 655             records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656             if records:
#     657                 return records
#
# /usr/local/lib/python3.11/dist-packages/kafka/consumer/group.py in _poll_once(self, timeout_ms, max_records, update_offsets)
#     700
#     701         timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702         self._client.poll(timeout_ms=timeout_ms)
#     703         # after the long poll, we should check whether the group needs to rebalance
#     704         # prior to returning data so that the group can stabilize faster
#
# /usr/local/lib/python3.11/dist-packages/kafka/client_async.py in poll(self, timeout_ms, future)
#     600                     timeout = max(0, timeout)  # avoid negative timeouts
#     601
# --> 602                 self._poll(timeout / 1000)
#     603
#     604             # called without the lock to avoid deadlock potential
#
# /usr/local/lib/python3.11/dist-packages/kafka/client_async.py in _poll(self, timeout)
#     632
#     633         start_select = time.time()
# --> 634         ready = self._selector.select(timeout)
#     635         end_select = time.time()
#     636         if self._sensors:
#
# /usr/lib/python3.11/selectors.py in select(self, timeout)
#     466             ready = []
#     467             try:
# --> 468                 fd_event_list = self._selector.poll(timeout, max_ev)
#     469             except InterruptedError:
#     470                 return ready
#
# KeyboardInterrupt:

# %% [markdown]
# Configure AWS CLI

# %%
# !pip install awscli
# Out:
# Collecting awscli
#   Downloading awscli-1.37.2-py3-none-any.whl.metadata (11 kB)
# Collecting botocore==1.36.2 (from awscli)
#   Downloading botocore-1.36.2-py3-none-any.whl.metadata (5.7 kB)
# Collecting docutils<0.17,>=0.10 (from awscli)
#   Downloading docutils-0.16-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting s3transfer<0.12.0,>=0.11.0 (from awscli)
#   Downloading s3transfer-0.11.1-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: PyYAML<6.1,>=3.10 in /usr/local/lib/python3.11/dist-packages (from awscli) (6.0.2)
# Collecting colorama<0.4.7,>=0.2.5 (from awscli)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting rsa<4.8,>=3.1.2 (from awscli)
#   Downloading rsa-4.7.2-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from botocore==1.36.2->awscli) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.11/dist-packages (from botocore==1.36.2->awscli) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.11/dist-packages (from botocore==1.36.2->awscli) (2.3.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.11/dist-packages (from rsa<4.8,>=3.1.2->awscli) (0.6.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore==1.36.2->awscli) (1.17.0)
# Downloading awscli-1.37.2-py3-none-any.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 58.5 MB/s eta 0:00:00
# Downloading botocore-1.36.2-py3-none-any.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 88.9 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading docutils-0.16-py2.py3-none-any.whl (548 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 548.2/548.2 kB 42.0 MB/s eta 0:00:00
# Downloading rsa-4.7.2-py3-none-any.whl (34 kB)
# Downloading s3transfer-0.11.1-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 9.5 MB/s eta 0:00:00
# Installing collected packages: rsa, docutils, colorama, botocore, s3transfer, awscli
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.9
#     Uninstalling rsa-4.9:
#       Successfully uninstalled rsa-4.9
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.21.2
#     Uninstalling docutils-0.21.2:
#       Successfully uninstalled docutils-0.21.2
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.36.1
#     Uninstalling botocore-1.36.1:
#       Successfully uninstalled botocore-1.36.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# aiobotocore 2.18.0 requires botocore<1.36.2,>=1.36.0, but you have botocore 1.36.2 which is incompatible.
# sphinx 8.1.3 requires docutils<0.22,>=0.20, but you have docutils 0.16 which is incompatible.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.12.0 which is incompatible.
# Successfully installed awscli-1.37.2 botocore-1.36.2 colorama-0.4.6 docutils-0.16 rsa-4.7.2 s3transfer-0.11.1

# %%
# !aws configure
# Out:
# AWS Access Key ID [None]: AKIA5FCD6EEG3XKS6Q7R
# AWS Secret Access Key [None]: 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
# Default region name [None]: eu-north-1
# Default output format [None]:

# %%
from s3fs import S3FileSystem
s3 = S3FileSystem()

# %%
for count,i in enumerate(consumer):
    with s3.open("s3://kafka-stock-jay/stock_market_{}.json".format(count), 'w') as file:
        json.dump(i.value, file)
# Out:
# ERROR:kafka.conn:<BrokerConnection node_id=0 host=16.171.32.64:9092 <connected> [IPv4 ('16.171.32.64', 9092)]>: socket disconnected
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.consumer.fetcher:Fetch to node 0 failed: KafkaConnectionError: socket disconnected
# ERROR:kafka.conn:<BrokerConnection node_id=0 host=16.171.32.64:9092 <connected> [IPv4 ('16.171.32.64', 9092)]>: socket disconnected
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.consumer.fetcher:Fetch to node 0 failed: KafkaConnectionError: socket disconnected
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ERROR:kafka.conn:Connect attempt to <BrokerConnection node_id=0 host=16.171.32.64:9092 <connecting> [IPv4 ('16.171.32.64', 9092)]> returned error 111. Disconnecting.
# WARNING:kafka.client:Node 0 connection failed -- refreshing metadata
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-c1f0a31b4003> in <cell line: 0>()
# ----> 1 for count,i in enumerate(consumer):
#       2     with s3.open("s3://kafka-stock-jay/stock_market_{}.json".format(count), 'w') as file:
#       3         json.dump(i.value, file)
#
# /usr/local/lib/python3.11/dist-packages/kafka/consumer/group.py in __next__(self)
#    1191             return self.next_v1()
#    1192         else:
# -> 1193             return self.next_v2()
#    1194
#    1195     def next_v2(self):
#
# /usr/local/lib/python3.11/dist-packages/kafka/consumer/group.py in next_v2(self)
#    1199                 self._iterator = self._message_generator_v2()
#    1200             try:
# -> 1201                 return next(self._iterator)
#    1202             except StopIteration:
#    1203                 self._iterator = None
#
# /usr/local/lib/python3.11/dist-packages/kafka/consumer/group.py in _message_generator_v2(self)
#    1114     def _message_generator_v2(self):
#    1115         timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116         record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117         for tp, records in six.iteritems(record_map):
#    1118             # Generators are stateful, and it is possible that the tp / records
#
# /usr/local/lib/python3.11/dist-packages/kafka/consumer/group.py in poll(self, timeout_ms, max_records, update_offsets)
#     653         remaining = timeout_ms
#     654         while True:
# --> 655             records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656             if records:
#     657                 return records
#
# /usr/local/lib/python3.11/dist-packages/kafka/consumer/group.py in _poll_once(self, timeout_ms, max_records, update_offsets)
#     700
#     701         timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702         self._client.poll(timeout_ms=timeout_ms)
#     703         # after the long poll, we should check whether the group needs to rebalance
#     704         # prior to returning data so that the group can stabilize faster
#
# /usr/local/lib/python3.11/dist-packages/kafka/client_async.py in poll(self, timeout_ms, future)
#     600                     timeout = max(0, timeout)  # avoid negative timeouts
#     601
# --> 602                 self._poll(timeout / 1000)
#     603
#     604             # called without the lock to avoid deadlock potential
#
# /usr/local/lib/python3.11/dist-packages/kafka/client_async.py in _poll(self, timeout)
#     632
#     633         start_select = time.time()
# --> 634         ready = self._selector.select(timeout)
#     635         end_select = time.time()
#     636         if self._sensors:
#
# /usr/lib/python3.11/selectors.py in select(self, timeout)
#     466             ready = []
#     467             try:
# --> 468                 fd_event_list = self._selector.poll(timeout, max_ev)
#     469             except InterruptedError:
#     470                 return ready
#
# KeyboardInterrupt:
